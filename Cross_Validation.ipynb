# %% [markdown]
# <a href="https://colab.research.google.com/github/SumitBhatt061/Regularization-and-optimization-/blob/main/Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm

# %%
X,y = datasets.load_iris(return_X_y=True)
X.shape,y.shape
# Out:
# ((150, 4), (150,))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.4,random_state=0)

# %%
clf=svm.SVC  (C=1,kernel='linear').fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
clf=svm.SVC(kernel='linear',C=1,random_state=42)
scores=cross_val_score(clf,X,y,cv=5)
scores
# Out:
# array([0.96666667, 1.        , 0.96666667, 0.96666667, 1.        ])

# %%
print(scores.mean())
# Out:
# 0.9800000000000001

# %%
print(scores.std())
# Out:
# 0.016329931618554516
